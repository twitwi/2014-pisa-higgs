# %% [markdown]
# Importing things

# %%
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Load the data with "dtype=None" to load it as strings (not all of them are numbers).

# %%
csv = np.genfromtxt("data/subtraining.csv", delimiter=",", dtype=None)

# %%
print csv[0,:]
# Out:
# ['EventId' 'DER_mass_MMC' 'DER_mass_transverse_met_lep' 'DER_mass_vis'
#  'DER_pt_h' 'DER_deltaeta_jet_jet' 'DER_mass_jet_jet' 'DER_prodeta_jet_jet'
#  'DER_deltar_tau_lep' 'DER_pt_tot' 'DER_sum_pt' 'DER_pt_ratio_lep_tau'
#  'DER_met_phi_centrality' 'DER_lep_eta_centrality' 'PRI_tau_pt'
#  'PRI_tau_eta' 'PRI_tau_phi' 'PRI_lep_pt' 'PRI_lep_eta' 'PRI_lep_phi'
#  'PRI_met' 'PRI_met_phi' 'PRI_met_sumet' 'PRI_jet_num' 'PRI_jet_leading_pt'
#  'PRI_jet_leading_eta' 'PRI_jet_leading_phi' 'PRI_jet_subleading_pt'
#  'PRI_jet_subleading_eta' 'PRI_jet_subleading_phi' 'PRI_jet_all_pt'
#  'Weight' 'Label']

# %% [markdown]
# It seems the first line is a header, the first column is an event ID and can be ignored.
# We decide to also ignore the two last columns (a probability for the simulation, and the label).
# There are actually two types of events: 'b' for background event, and 's' for signal events.

# %% [markdown]
# The loaded csv data were in string formats, for the actual "data" features, we force it to be interpreted as 'float' (real number).

# %%
head = csv[0,:]
data = np.array(csv[1:,1:-2], dtype=float) # col 1 is an ID, last are weight and label
labels = csv[1:,-1]

# %%
print head.shape
print data.shape
print labels.shape
# Out:
# (33,)
# (10001, 30)
# (10001,)

# %% [markdown]
# Ho separato i dati iniziali in:
# Tutti gli header in un vettore (compresi Event ID, Weight, Label)
# Tutti i dati in una matrice
# Tutte le label in un vettore

# %%
print "Missing values: ",(data == -999).sum()
print "Rows with missing values: ", (data == -999).any(axis=1).sum()
print "Rows without missing values: ", (data != -999).all(axis=1).sum()
# Out:
# Missing values:  63614
# Rows with missing values:  7306
# Rows without missing values:  2695

# %%
indicesOfCleanRows = (data != -999).all(axis=1)
onlyclean = data[indicesOfCleanRows,:]
onlycleanlabels = labels[ indicesOfCleanRows ]
print onlyclean.shape
print onlycleanlabels.shape
# Out:
# (2695, 30)
# (2695,)

# %% [markdown]
# Check if the data have been actually cleaned (as I know that there are Missing values)

# %%
assert onlyclean.shape<data.shape

# %% [markdown]
# TODO: I'm not sure of my cleaning code, I should check that it works...
# SOLVED: .all() instead of .any() procedure must be called.

# %%
mu = onlyclean.mean(0)
mu.shape
# Out:
# (30,)

# %%
std = (onlyclean - mu).std(0)
std.shape
# Out:
# (30,)

# %%
cov = np.matrix(onlyclean - mu)/std
cov = cov.T * cov
cov.shape
# Out:
# (30, 30)

# %%
plt.imshow(cov, interpolation='nearest')

# %% [markdown]
# We extract the eigenvectors and eigenvalues (we print the eigenvalues, we'll only use the vectors)

# %%
eigenValues,v = np.linalg.eig(cov)
print eigenValues
print v.shape
# Out:
# [  1.70080061e+04   9.11226000e+03   7.16182879e+03   4.87737386e+03
#    4.73390673e+03   4.55938195e+03   4.25471925e+03   3.42977010e+03
#    2.93342457e+03   2.88272313e+03   2.68655029e+03   2.20195176e+03
#    2.04781273e+03   1.72240490e+03   1.66994063e+03   1.52719319e+03
#    1.49622936e+03   1.33631905e+03   1.10590212e+03   1.05161036e+03
#    8.12001238e+02   5.47511956e+02   4.61155360e+02   3.54772424e+02
#    1.40950889e+02   9.21694158e+01   7.86445183e+01   2.59861425e+02
#    3.03623873e+02   2.97905578e-08]
# (30, 30)

# %% [markdown]
# Extract and plot the first 4 eigenvectors.

# %%
firstVs = v[:,0:4]
plt.imshow(firstVs, interpolation='nearest')
firstVs.shape
# Out:
# (30, 4)

# %%
proj = ((onlyclean-mu)/std) * firstVs
proj.shape
# Out:
# (2695, 4)

# %%
s = proj[onlycleanlabels == 's'] #signal
b = proj[onlycleanlabels == 'b'] #background
plt.scatter(s[:,0], s[:,1], c='r', marker='o')
plt.scatter(b[:,0], b[:,1], c='g', marker='o', alpha=.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-81-852688439285> in <module>()
#       1 s = proj[onlycleanlabels == 's'] #signal
#       2 b = proj[onlycleanlabels == 'b'] #background
# ----> 3 plt.scatter(s[:,0], s[:,1], c='r', marker='o')
#       4 plt.scatter(b[:,0], b[:,1], c='g', marker='o', alpha=.3)
#       5 plt.show()
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, hold, **kwargs)
#    3085         ret = ax.scatter(x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3086                          vmin=vmin, vmax=vmax, alpha=alpha,
# -> 3087                          linewidths=linewidths, verts=verts, **kwargs)
#    3088         draw_if_interactive()
#    3089     finally:
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    6245             self.cla()
#    6246
# -> 6247         self._process_unit_info(xdata=x, ydata=y, kwargs=kwargs)
#    6248         x = self.convert_xunits(x)
#    6249         y = self.convert_yunits(y)
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in _process_unit_info(self, xdata, ydata, kwargs)
#    1683             # we only need to update if there is nothing set yet.
#    1684             if not self.xaxis.have_units():
# -> 1685                 self.xaxis.update_units(xdata)
#    1686             #print '\tset from xdata', self.xaxis.units
#    1687
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in update_units(self, data)
#    1334         """
#    1335
# -> 1336         converter = munits.registry.get_converter(data)
#    1337         if converter is None:
#    1338             return False
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# ...
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/matplotlib/units.pyc in get_converter(self, x)
#     146             except AttributeError:
#     147                 # not a masked_array
# --> 148                 converter = self.get_converter(xravel[0])
#     149                 return converter
#     150
#
# /home/chionatan/anaconda/lib/python2.7/site-packages/numpy/matrixlib/defmatrix.pyc in __getitem__(self, index)
#     314
#     315         try:
# --> 316             out = N.ndarray.__getitem__(self, index)
#     317         finally:
#     318             self._getitem = False
#
# RuntimeError: maximum recursion depth exceeded

# %% [markdown]
# Make a plotting function. Plot both red over white and white over red.

# %%
def draw(d1, d2, sub1, sub2):
    print "Plotting principal component",d1,"versus principal component", d2
    fig,(p1,p2) = plt.subplots(nrows=2)
    p1.scatter(sub1[:,d1], sub1[:,d2], c='r')
    p1.scatter(sub2[:,d1], sub2[:,d2], c='g', alpha=.5)
    p2.scatter(sub2[:,d1], sub2[:,d2], c='g')
    p2.scatter(sub1[:,d1], sub1[:,d2], c='r', alpha=.5)
    plt.show()

# %%
s = proj[onlycleanlabels == 's'] #signal
b = proj[onlycleanlabels == 'b'] #background
draw(0,1, s,b)
draw(2,3, s,b)
draw(0,2, s,b)
draw(1,3, s,b)
